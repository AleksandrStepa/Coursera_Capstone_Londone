# %% [markdown]
# # Introduction

# %% [markdown]
# A novice businessman who does not have a lot of capital should choose an inexpensive and reliable business.
# One of the low thresholds of entry into the market has a coffee shop business.
# In my project I want to help a budding businessman choose an borough of London to open the coffee shop

# %% [markdown]
# # Data

# %% [markdown]
# ## To solve this problem I will need:

# %% [markdown]
# 1. data on London boroughs and their coordinates
# The names of the boroughs I got from the site https://www.spareroom.co.uk/content/info-flatsharing/london-postcodes
# using the library BeautifulSoup for parsering html
# Coordinates boroughs received with the help Google API service

# %% [markdown]
# 2. data on coffee shops in each borough
# 3. rating of coffee shops in each borough
#  This data I got with Foursquare

# %% [markdown]
# 4. Some statistics
# This data I got from the site https://startups.co.uk/starting-a-business-in-london-borough-by-borough-statistics
# using the library BeautifulSoup for parsering html
# The start-up ecosystem

# %% [markdown]
# # Methodology

# %% [markdown]
# 1. At first I tried to find London borough data through postcodes, but it turned out that the basic data is presented for 32 boroughs that do not match the postcode. Information about boroughs name and such statistical information as 'No of new start-ups', 'No of new start-ups per sq km', 'Survival rate %', 'No of micro businesses', 'Micro business %', 'No of small businesses I found on the site

# %% [markdown]
# 2. Then I found each coffee shop in each borough and the rating of each coffee shop, if the rating was not I took it equal to zero.After that I counted the number of coffee shops in each borough and the average rating of coffee shops by borough

# %% [markdown]
# 3. To determine commercial demand I calculated the number of parks and offices per coffee shop in each borough

# %% [markdown]
# 4. I applied cluster analysis to this data. Previously normalized this data. The optimal k I picked up is equal to three

# %% [markdown]
# 5. In each cluster I determined the average of the features

# %% [markdown]
# # Results

# %% [markdown]
# The model divided the data into the following 3 clusters

# %% [markdown]
# 1. Cluster:
#     No of new start-ups              2145.000000
#     No of new start-ups per sq km      70.000000
#     Survival rate %                    39.900000
#     No of micro businesses           9687.500000
#     Micro business %                   92.100000
#     No of small businesses            686.666667
#     No of Coffee Shops                 20.500000
#     No of Office                        0.739929
#     No of Park                          0.683333
#     rating                              6.930560

# %% [markdown]
# 2. Cluster:
#     No of new start-ups               2520.000000
#     No of new start-ups per sq km       73.875000
#     Survival rate %                     39.237500
#     No of micro businesses           11175.833333
#     Micro business %                    91.437500
#     No of small businesses             859.375000
#     No of Coffee Shops                  26.875000
#     No of Office                         1.035114
#     No of Park                           0.917896
#     rating                               7.022494

# %% [markdown]
# 3. Cluster:
#     No of new start-ups               5076.666667
#     No of new start-ups per sq km      493.666667
#     Survival rate %                     36.466667
#     No of micro businesses           24786.666667
#     Micro business %                    83.900000
#     No of small businesses            3586.666667
#     No of Coffee Shops                  27.333333
#     No of Office                         0.911111
#     No of Park                           0.911111
#     rating                               7.011858

# %%
df_london
# Out:
#     Unnamed: 0               Borough  No of new start-ups  \
# 0            0    Barking , Dagenham                 1310
# 1            1                Barnet                 3985
# 2            2                Bexley                 1455
# 3            3                 Brent                 2585
# 4            4               Bromley                 2190
# 5            5                Camden                 4375
# 6            6        City of London                 2610
# 7            7               Croydon                 2390
# 8            8                Ealing                 3110
# 9            9               Enfield                 2305
# 10          10             Greenwich                 1690
# 11          11               Hackney                 3245
# 12          12  Hammersmith , Fulham                 2380
# 13          13              Haringey                 2190
# 14          14                Harrow                 2390
# ...

# %% [markdown]
# # Discussion

# %% [markdown]
# The best signs are in boroughs from the third cluster, but these are Central London and the cost of renting there is incredibly high, so the optimal areas for opening coffee shops will be borough from the second cluster, where we have good indicators on the number of parks and offices per coffee shop, as well as the survival of startups

# %% [markdown]
# # Conclusion

# %% [markdown]
# I have not been able to find free data on the cost of commercial rent, and the rating data is simulated, as it provides only 50 premium queries. But on the basis of available data it turned out to divide the boroughs into clusters and make recommendations
